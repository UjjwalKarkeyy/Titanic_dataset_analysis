# %%
import pandas as pd
import math

# %%
temp_data = pd.read_csv('titanic.csv')

# %%
temp_data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S

# %%
temp_data.shape
# Out:
# (418, 12)

# %%
# Meaning of the columns:

# Pclass: Passenger class, so if they were from 1st class, 2nd class, or etc. Class gives a measure for the economic value of the seat

# SibSp: The number of siblings or spouse that the passenger had aboard

# Parch: The number of children or parent the passenger had aboard

# Cabin: If the passenger had any cabin, which cabin number were they seated at

# Embarked: Which gate did they use to aboard the ship

# %%
data = temp_data
data.tail()
# Out:
#      PassengerId  Survived  Pclass                          Name     Sex  \
# 413         1305         0       3            Spector, Mr. Woolf    male
# 414         1306         1       1  Oliva y Ocana, Dona. Fermina  female
# 415         1307         0       3  Saether, Mr. Simon Sivertsen    male
# 416         1308         0       3           Ware, Mr. Frederick    male
# 417         1309         0       3      Peter, Master. Michael J    male
#
#       Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# 413   NaN      0      0           A.5. 3236    8.0500   NaN        S
# 414  39.0      0      0            PC 17758  108.9000  C105        C
# 415  38.5      0      0  SOTON/O.Q. 3101262    7.2500   NaN        S
# 416   NaN      0      0              359309    8.0500   NaN        S
# 417   NaN      1      1                2668   22.3583   NaN        C

# %%
data['Sex'] = [ i.capitalize() for i in data['Sex']]

# %%
data.iloc[10:20]
# Out:
#     PassengerId  Survived  Pclass  \
# 10          902         0       3
# 11          903         0       1
# 12          904         1       1
# 13          905         0       2
# 14          906         1       1
# 15          907         1       2
# 16          908         0       2
# 17          909         0       3
# 18          910         1       3
# 19          911         1       3
#
#                                                  Name     Sex   Age  SibSp  \
# 10                                   Ilieff, Mr. Ylio    Male   NaN      0
# 11                         Jones, Mr. Charles Cresson    Male  46.0      0
# 12      Snyder, Mrs. John Pillsbury (Nelle Stevenson)  Female  23.0      1
# 13                               Howard, Mr. Benjamin    Male  63.0      1
# 14  Chaffee, Mrs. Herbert Fuller (Carrie Constance...  Female  47.0      1
# 15      del Carlo, Mrs. Sebastiano (Argenia Genovesi)  Female  24.0      1
# ...

# %%
data['Age'] = [ 0 if math.isnan(i) else i for i in data['Age']]

# %%
data['Age'] = [math.floor(i) for i in data['Age']]

# %%
data.tail()
# Out:
#      PassengerId  Survived  Pclass                          Name     Sex  Age  \
# 413         1305         0       3            Spector, Mr. Woolf    Male    0
# 414         1306         1       1  Oliva y Ocana, Dona. Fermina  Female   39
# 415         1307         0       3  Saether, Mr. Simon Sivertsen    Male   38
# 416         1308         0       3           Ware, Mr. Frederick    Male    0
# 417         1309         0       3      Peter, Master. Michael J    Male    0
#
#      SibSp  Parch              Ticket      Fare Cabin Embarked
# 413      0      0           A.5. 3236    8.0500   NaN        S
# 414      0      0            PC 17758  108.9000  C105        C
# 415      0      0  SOTON/O.Q. 3101262    7.2500   NaN        S
# 416      0      0              359309    8.0500   NaN        S
# 417      1      1                2668   22.3583   NaN        C

# %%
data.Ticket.unique()
# Out:
# array(['330911', '363272', '240276', '315154', '3101298', '7538',
#        '330972', '248738', '2657', 'A/4 48871', '349220', '694', '21228',
#        '24065', 'W.E.P. 5734', 'SC/PARIS 2167', '233734', '2692',
#        'STON/O2. 3101270', '2696', 'PC 17603', 'C 17368', 'PC 17598',
#        'PC 17597', 'PC 17608', 'A/5. 3337', '113509', '2698', '113054',
#        '2662', 'SC/AH 3085', 'C.A. 31029', 'C.A. 2315', 'W./C. 6607',
#        '13236', '2682', '342712', '315087', '345768', '1601', '349256',
#        '113778', 'SOTON/O.Q. 3101263', '237249', '11753',
#        'STON/O 2. 3101291', 'PC 17594', '370374', '11813', 'C.A. 37671',
#        '13695', 'SC/PARIS 2168', '29105', '19950', 'SC/A.3 2861',
#        '382652', '349230', '348122', '386525', '349232', '237216',
#        '347090', '334914', 'F.C.C. 13534', '330963', '113796', '2543',
#        '382653', '349211', '3101297', 'PC 17562', '113503', '359306',
#        '11770', '248744', '368702', '2678', 'PC 17483', '19924', '349238',
# ...

# %%
data['Ticket'] = [ i.strip() for i in data['Ticket']]

# %%
data['Ticket'] = [ i.split(" ")[1] if " " in i else i for i in data['Ticket']]

# %%
data.tail()
# Out:
#      PassengerId  Survived  Pclass                          Name     Sex  Age  \
# 413         1305         0       3            Spector, Mr. Woolf    Male    0
# 414         1306         1       1  Oliva y Ocana, Dona. Fermina  Female   39
# 415         1307         0       3  Saether, Mr. Simon Sivertsen    Male   38
# 416         1308         0       3           Ware, Mr. Frederick    Male    0
# 417         1309         0       3      Peter, Master. Michael J    Male    0
#
#      SibSp  Parch   Ticket      Fare Cabin Embarked
# 413      0      0     3236    8.0500   NaN        S
# 414      0      0    17758  108.9000  C105        C
# 415      0      0  3101262    7.2500   NaN        S
# 416      0      0   359309    8.0500   NaN        S
# 417      1      1     2668   22.3583   NaN        C

# %%
data['Embarked'].iloc[10:20]
# Out:
# 10    S
# 11    S
# 12    S
# 13    S
# 14    S
# 15    C
# 16    Q
# 17    C
# 18    S
# 19    C
# Name: Embarked, dtype: object
